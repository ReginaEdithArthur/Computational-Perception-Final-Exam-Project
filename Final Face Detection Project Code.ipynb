# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.39 🚀 Python-3.10.12 torch-2.5.1+cpu CPU (Intel Xeon 2.00GHz)
# Setup complete ✅ (96 CPUs, 334.6 GB RAM, 17.0/225.3 GB disk)

# %%
# Train YOLO11n on COCO8 for 3 epochs
# !yolo task=detect mode=train model=yolo11n.pt data=/content/drive/MyDrive/Computational_Perception_Final_Exams_Project/ultralytics/ultralytics/cfg/datasets/data.yaml epochs=30 imgsz=640 plots=True project=/content/drive/MyDrive/Computational_Perception_Final_Exams_Project/Results save_period=5
# Out:
# Ultralytics 8.3.39 🚀 Python-3.10.12 torch-2.5.1+cpu CPU (Intel Xeon 2.00GHz)
# ...

# %%
# Validate best.pt
# !yolo task=detect mode=val model=/content/drive/MyDrive/Computational_Perception_Final_Exams_Project/Results/train/weights/best.pt data=/content/drive/MyDrive/Computational_Perception_Final_Exams_Project/ultralytics/ultralytics/cfg/datasets/data.yaml plots=True project=/content/drive/MyDrive/Computational_Perception_Final_Exams_Project/Results save=True
# Out:
# Ultralytics 8.3.39 🚀 Python-3.10.12 torch-2.5.1+cpu CPU (Intel Xeon 2.00GHz)
# YOLO11n summary (fused): 238 layers, 2,582,347 parameters, 0 gradients, 6.3 GFLOPs
# val: Scanning /content/drive/.shortcut-targets-by-id/1YjVLU5SSSLi5z7BF-spNNCsWvbG7qNQF/Computational_Perception_Final_Exams_Project/Data/labels/val... 3226 images, 0 backgrounds, 1 corrupt: 100% 3226/3226 [01:02<00:00, 51.70it/s]
# val: WARNING ⚠️ /content/drive/.shortcut-targets-by-id/1YjVLU5SSSLi5z7BF-spNNCsWvbG7qNQF/Computational_Perception_Final_Exams_Project/Data/images/val/image_1060.jpg: 1 duplicate labels removed
# val: WARNING ⚠️ /content/drive/.shortcut-targets-by-id/1YjVLU5SSSLi5z7BF-spNNCsWvbG7qNQF/Computational_Perception_Final_Exams_Project/Data/images/val/image_1885.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.002]
# ...

# %%
# Run inference on test images with best.pt
# !yolo task=detect mode=predict model=/content/drive/MyDrive/Computational_Perception_Final_Exams_Project/Results/train/weights/best.pt  conf=0.25 source=/content/drive/MyDrive/Computational_Perception_Final_Exams_Project/Data/images/test plots=True project=/content/drive/MyDrive/Computational_Perception_Final_Exams_Project/Results save=True
# Out:
# Streaming output truncated to the last 5000 lines.
# image 11101/16097 /content/drive/MyDrive/Computational_Perception_Final_Exams_Project/Data/images/test/45_Balloonist_Balloonist_45_145.jpg: 416x640 7 faces, 48.0ms
# image 11102/16097 /content/drive/MyDrive/Computational_Perception_Final_Exams_Project/Data/images/test/45_Balloonist_Balloonist_45_148.jpg: 384x640 1 face, 44.8ms
# image 11103/16097 /content/drive/MyDrive/Computational_Perception_Final_Exams_Project/Data/images/test/45_Balloonist_Balloonist_45_154.jpg: 384x640 10 faces, 43.0ms
# image 11104/16097 /content/drive/MyDrive/Computational_Perception_Final_Exams_Project/Data/images/test/45_Balloonist_Balloonist_45_158.jpg: 512x640 1 face, 49.5ms
# image 11105/16097 /content/drive/MyDrive/Computational_Perception_Final_Exams_Project/Data/images/test/45_Balloonist_Balloonist_45_159.jpg: 640x384 1 face, 80.7ms
# ...

# %%
# Validate last.pt
# !yolo task=detect mode=val model=/content/drive/MyDrive/Computational_Perception_Final_Exams_Project/Results/train/weights/last.pt data=/content/drive/MyDrive/Computational_Perception_Final_Exams_Project/ultralytics/ultralytics/cfg/datasets/data.yaml plots=True project=/content/drive/MyDrive/Computational_Perception_Final_Exams_Project/Results save=True
# Out:
# Ultralytics 8.3.39 🚀 Python-3.10.12 torch-2.5.1+cpu CPU (Intel Xeon 2.00GHz)
# YOLO11n summary (fused): 238 layers, 2,582,347 parameters, 0 gradients, 6.3 GFLOPs
# val: Scanning /content/drive/.shortcut-targets-by-id/1YjVLU5SSSLi5z7BF-spNNCsWvbG7qNQF/Computational_Perception_Final_Exams_Project/Data/labels/val.cache... 3226 images, 0 backgrounds, 1 corrupt: 100% 3226/3226 [00:00<?, ?it/s]
# val: WARNING ⚠️ /content/drive/.shortcut-targets-by-id/1YjVLU5SSSLi5z7BF-spNNCsWvbG7qNQF/Computational_Perception_Final_Exams_Project/Data/images/val/image_1060.jpg: 1 duplicate labels removed
# val: WARNING ⚠️ /content/drive/.shortcut-targets-by-id/1YjVLU5SSSLi5z7BF-spNNCsWvbG7qNQF/Computational_Perception_Final_Exams_Project/Data/images/val/image_1885.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [      1.002]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 202/202 [03:06<00:00,  1.08it/s]
# ...

# %%
# Run inference on test images with last.pt
# !yolo task=detect mode=predict model=/content/drive/MyDrive/Computational_Perception_Final_Exams_Project/Results/train/weights/last.pt  conf=0.25 source=/content/drive/MyDrive/Computational_Perception_Final_Exams_Project/Data/images/test plots=True project=/content/drive/MyDrive/Computational_Perception_Final_Exams_Project/Results save=True
# Out:
# Streaming output truncated to the last 5000 lines.
# image 11101/16097 /content/drive/MyDrive/Computational_Perception_Final_Exams_Project/Data/images/test/45_Balloonist_Balloonist_45_145.jpg: 416x640 7 faces, 45.3ms
# image 11102/16097 /content/drive/MyDrive/Computational_Perception_Final_Exams_Project/Data/images/test/45_Balloonist_Balloonist_45_148.jpg: 384x640 1 face, 46.7ms
# image 11103/16097 /content/drive/MyDrive/Computational_Perception_Final_Exams_Project/Data/images/test/45_Balloonist_Balloonist_45_154.jpg: 384x640 10 faces, 45.0ms
# image 11104/16097 /content/drive/MyDrive/Computational_Perception_Final_Exams_Project/Data/images/test/45_Balloonist_Balloonist_45_158.jpg: 512x640 1 face, 49.8ms
# image 11105/16097 /content/drive/MyDrive/Computational_Perception_Final_Exams_Project/Data/images/test/45_Balloonist_Balloonist_45_159.jpg: 640x384 1 face, 81.1ms
# ...

# %%
#best.pt renamed as face_detection_model before exportion
# !yolo export model=/content/drive/MyDrive/Computational_Perception_Final_Exams_Project/Results/train/weights/face_detection_model.pt format=onnx project=/content/drive/MyDrive/Computational_Perception_Final_Exams_Project/Results save=True
# Out:
# Ultralytics 8.3.39 🚀 Python-3.10.12 torch-2.5.1+cpu CPU (Intel Xeon 2.00GHz)
# YOLO11n summary (fused): 238 layers, 2,582,347 parameters, 0 gradients, 6.3 GFLOPs
#
# PyTorch: starting from '/content/drive/MyDrive/Computational_Perception_Final_Exams_Project/Results/train/weights/face_detection_model.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 5, 8400) (5.2 MB)
# requirements: Ultralytics requirements ['onnx>=1.12.0', 'onnxslim', 'onnxruntime'] not found, attempting AutoUpdate...
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.0/16.0 MB 309.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.7/142.7 kB 352.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 278.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 239.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 275.1 MB/s eta 0:00:00
# ...
#
# ...
